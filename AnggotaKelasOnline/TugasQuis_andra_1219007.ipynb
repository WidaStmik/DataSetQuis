# %%
from google.colab import drive
drive.mount('/content/drives/')
# Out:
# ---------------------------------------------------------------------------
# MessageError                              Traceback (most recent call last)
# <ipython-input-1-525b5b753894> in <cell line: 2>()
#       1 from google.colab import drive
# ----> 2 drive.mount('/content/drives/')
#
# /usr/local/lib/python3.10/dist-packages/google/colab/drive.py in mount(mountpoint, force_remount, timeout_ms, readonly)
#     101 def mount(mountpoint, force_remount=False, timeout_ms=120000, readonly=False):
#     102   """Mount your Google Drive at the specified mountpoint path."""
# --> 103   return _mount(
#     104       mountpoint,
#     105       force_remount=force_remount,
#
# /usr/local/lib/python3.10/dist-packages/google/colab/drive.py in _mount(mountpoint, force_remount, timeout_ms, ephemeral, readonly)
#     130   )
#     131   if ephemeral:
# --> 132     _message.blocking_request(
#     133         'request_auth', request={'authType': 'dfs_ephemeral'}, timeout_sec=None
# ...

# %%
# !pip install deepface
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.6/49.6 kB 2.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.3/88.3 kB 3.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.5/79.5 kB 8.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 36.5 MB/s eta 0:00:00
# ...
#   Created wheel for fire: filename=fire-0.5.0-py2.py3-none-any.whl size=116952 sha256=8f59aff03b487e59b4fde5876f66334a3c1eb750452d4853a060c7e6b874ce3e
#   Stored in directory: /root/.cache/pip/wheels/f7/f1/89/b9ea2bf8f80ec027a88fef1d354b3816b4d3d29530988972f6
# Successfully built fire
# ...

# %%
import os
from pathlib import path
folder = '/content/drives/MyDrive/Salinan Wajah'

def load_images_from_folder(folder):
    images = []   
    for filename in os.listdir(folder):
        img = cv2.imread(os.path.join(folder,filename))
        #if img is not None:
        images.append(img)
        labels.append(Path(filename).stem)
    return images,labels
x,lbl=load_images_from_folder(folder)
countData=len(x)

# %%
import cv2
from google.colab.patches import cv2_imshow
img=cv2.imread('/content/drive/MyDrive/Salinan Wajah/Salinan cheol kamjagia.jpg', cv2.IMREAD_UNCHANGED)

cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=663x663 at 0x7FEC3C733880>

# %%
import cv2
from google.colab.patches import cv2_imshow
img=cv2.imread('/content/drive/MyDrive/Salinan Wajah/Salinan cheol marah rawrr.jpg', cv2.IMREAD_UNCHANGED)

cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=1049x1057 at 0x7FEC3C5CDA00>

# %%
import cv2
from google.colab.patches import cv2_imshow
img=cv2.imread('/content/drive/MyDrive/Salinan Wajah/Salinan markodoy menangis.jpg', cv2.IMREAD_UNCHANGED)

cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=736x736 at 0x7FEC3C855A00>

# %%
import cv2
from google.colab.patches import cv2_imshow
img=cv2.imread('/content/drive/MyDrive/Salinan Wajah/Salinan markodoy smile.jpg', cv2.IMREAD_UNCHANGED)

cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=460x365 at 0x7FEC3C855940>

# %%
import cv2
from google.colab.patches import cv2_imshow
img=cv2.imread('/content/drive/MyDrive/Salinan Wajah/Salinan nonu b aja tapi tentu saja tidak b aja.jpg', cv2.IMREAD_UNCHANGED)

cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=956x956 at 0x7FEC3C5CDC10>

# %% [markdown]
# bagian baru

# %%
#detectors facenet
detectors = ["opencv", "ssd", "mtcnn", "dlib", "retinaface"]
result = DeepFace.verify(images[0],images[1], detector_backend=detectors[1],model_name="Facenet")
result
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-26-cfa5139d711b> in <cell line: 2>()
#       1 detectors = ["opencv", "ssd", "mtcnn", "dlib", "retinaface"]
# ----> 2 result = DeepFace.verify(images[0],images[1], detector_backend=detectors[1],model_name="Facenet")
#       3 result
#
# NameError: name 'DeepFace' is not defined

# %%
#detectors ovencv
detectors = ["opencv", "ssd", "mtcnn", "dlib", "retinaface"]
result = DeepFace.verify(images[0],images[1], detector_backend=detectors[0])
result
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-51b4996c470c> in <cell line: 3>()
#       1 #detectors ovencv
#       2 detectors = ["opencv", "ssd", "mtcnn", "dlib", "retinaface"]
# ----> 3 result = DeepFace.verify(images[0],images[1], detector_backend=detectors[0])
#       4 result
#
# NameError: name 'DeepFace' is not defined
